# %%
from pyqpp import *
from matplotlib import pyplot as plt

# %%
qc = QCircuit(1, 1)
qc.gate(gates.H, 0)
qc.measure_all()

# %%
qengine = QEngine(qc)
qengine.execute(1000)

# %%
stats = qengine.get_stats()
plt.bar(stats.keys(), stats.values())
plt.show()

# %%
qc = QCircuit(2, 2)
qc.gate(gates.H, 0)
qc.CTRL(gates.X, 0, 1)
qc.measure_all()

# %%
qengine = QEngine(qc)
qengine.execute(1000)

# %%
stats = qengine.get_stats()
plt.bar(stats.keys(), stats.values())
plt.show()

# %%
qengine = QNoisyEngine(qc, QubitDepolarizingNoise(0.01))

# %%
qengine.execute(1000)

# %%
stats = qengine.get_stats()
plt.bar(stats.keys(), stats.values())
plt.show()
